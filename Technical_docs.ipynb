# %% [markdown]
# <a href="https://colab.research.google.com/github/Th3Bard/Technical-Discussion/blob/main/Technical_docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %%
def hello():
  return "hi"
hello()
# Out:
# 'hi'

# %% [markdown]
# ## EDA

# %% [markdown]
# ### this is a markdown heading
#
# *one
# *two

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Conclusion
